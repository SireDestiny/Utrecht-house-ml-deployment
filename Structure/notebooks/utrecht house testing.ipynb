# %%
import json
import requests

# %%
url = 'http://1711-35-229-87-76.ngrok.io/house_prediction'

# %%
input = ({'zipcode': 3800,
   'lot_len': 35.6,
   'lot_area': 673,
   'house_area':221,
   'garden_size': 621,
   'y_coor': 5186,
   'energy_eff':0})


json_data = json.dumps(input)
response = requests.post(url, data=json_data)
print(response.text)
# Out:
# 334777.7475201837
